# %%
#import the modules
import os
import glob
import pandas as pd

# %% [markdown]
# ## Uniting files from `general` directory

# %%
#read the path
file_path = 'general'

# %%
#list all the files from the directory
file_list = os.listdir(file_path)
file_list
# Out:
# ['guardian-article-data_start-date-2018-01-01_end-date-2018-03-31_general.csv',
#  'guardian-article-data_start-date-2018-04-01_end-date-2018-06-30_general.csv',
#  'guardian-article-data_start-date-2018-07-01_end-date-2018-12-31_general.csv',
#  'guardian-article-data_start-date-2019-01-01_end-date-2019-06-30_general.csv',
#  'guardian-article-data_start-date-2019-07-01_end-date-2019-12-31_general.csv',
#  'guardian-article-data_start-date-2020-01-01_end-date-2020-03-31_general.csv',
#  'guardian-article-data_start-date-2020-04-01_end-date-2020-06-30_general.csv',
#  'guardian-article-data_start-date-2020-07-01_end-date-2020-12-31_general.csv',
#  'guardian-article-data_start-date-2021-01-01_end-date-2021-06-30_general.csv',
#  'guardian-article-data_start-date-2021-07-01_end-date-2021-12-31_general.csv',
#  'guardian-article-data_start-date-2022-01-01_end-date-2022-06-30_general.csv',
#  'guardian-article-data_start-date-2022-07-01_end-date-2022-11-11_general.csv',
#  'guardian-article-data_start-date-2022-11-12_end-date-2022-11-13_general.csv']

# %%
csv_files = glob.glob('{}/*{}.{}'.format('general','_general','csv'))
csv_files
# Out:
# ['general\\guardian-article-data_start-date-2018-01-01_end-date-2018-03-31_general.csv',
#  'general\\guardian-article-data_start-date-2018-04-01_end-date-2018-06-30_general.csv',
#  'general\\guardian-article-data_start-date-2018-07-01_end-date-2018-12-31_general.csv',
#  'general\\guardian-article-data_start-date-2019-01-01_end-date-2019-06-30_general.csv',
#  'general\\guardian-article-data_start-date-2019-07-01_end-date-2019-12-31_general.csv',
#  'general\\guardian-article-data_start-date-2020-01-01_end-date-2020-03-31_general.csv',
#  'general\\guardian-article-data_start-date-2020-04-01_end-date-2020-06-30_general.csv',
#  'general\\guardian-article-data_start-date-2020-07-01_end-date-2020-12-31_general.csv',
#  'general\\guardian-article-data_start-date-2021-01-01_end-date-2021-06-30_general.csv',
#  'general\\guardian-article-data_start-date-2021-07-01_end-date-2021-12-31_general.csv',
#  'general\\guardian-article-data_start-date-2022-01-01_end-date-2022-06-30_general.csv',
#  'general\\guardian-article-data_start-date-2022-07-01_end-date-2022-11-11_general.csv',
#  'general\\guardian-article-data_start-date-2022-11-12_end-date-2022-11-13_general.csv']

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file,sep=';')
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
#         id_num                                                 id     type  \
# 0            1  money/2018/jan/01/protests-planned-uk-rail-sta...  article
# 1            2  crosswords/2018/jan/01/annotated-solutions-for...  article
# 2            3     crosswords/2018/jan/01/genius-crossword-no-175  article
# 3            4  education/2018/jan/01/toby-young-universities-...  article
# 4            5  uk-news/2018/jan/01/prince-of-wales-charitable...  article
# ...        ...                                                ...      ...
# 365653     312  world/2022/nov/13/mines-looting-no-power-khers...  article
# 365654     313  sport/2022/nov/13/russell-admits-tears-were-fl...  article
# 365655     314  uk-news/2022/nov/13/joe-biden-to-meet-rishi-su...  article
# 365656     315  uk-news/2022/nov/13/sunak-says-higher-taxes-an...  article
# 365657     316  tv-and-radio/2022/nov/13/young-black-and-right...  article
#
#            sectionId         sectionName    webPublicationDate  \
# 0              money               Money  2018-01-01T00:01:11Z
# 1         crosswords          Crosswords  2018-01-01T00:01:11Z
# 2         crosswords          Crosswords  2018-01-01T00:01:11Z
# 3          education           Education  2018-01-01T00:01:12Z
# 4            uk-news             UK news  2018-01-01T00:39:36Z
# ...              ...                 ...                   ...
# 365653         world          World news  2022-11-13T22:19:22Z
# 365654         sport               Sport  2022-11-13T22:23:14Z
# 365655       uk-news             UK news  2022-11-13T22:30:22Z
# 365656       uk-news             UK news  2022-11-13T22:30:22Z
# 365657  tv-and-radio  Television & radio  2022-11-13T22:55:22Z
#
#                                                  webTitle  isHosted  \
# 0       Protests planned at UK rail stations to mark s...     False
# 1                      Annotated solutions for Genius 174     False
# 2                                 Genius crossword No 175     False
# 3       Toby Young to help lead government's new unive...     False
# 4       Prince of Wales Charitable Foundation halves d...     False
# ...                                                   ...       ...
# 365653     Zelenskiy accuses Russia of Kherson war crimes     False
# 365654  Russell admits ‘tears were flooding’ after emo...     False
# 365655  Biden to meet Sunak as pressure grows on PM ov...     False
# 365656  Sunak says higher taxes and spending cuts need...     False
# 365657  Young, Black and Right-Wing review – you’ll ne...     False
#
#                 pillarId pillarName
# 0       pillar/lifestyle  Lifestyle
# 1       pillar/lifestyle  Lifestyle
# 2       pillar/lifestyle  Lifestyle
# 3            pillar/news       News
# 4            pillar/news       News
# ...                  ...        ...
# 365653       pillar/news       News
# 365654      pillar/sport      Sport
# 365655       pillar/news       News
# 365656       pillar/news       News
# 365657       pillar/arts       Arts
#
# [365658 rows x 10 columns]

# %%
df_append['webPublicationDateTime'] = df_append['webPublicationDate']
df_append['webPublicationDate'] = df_append['webPublicationDate'].str.split('T').str[0]

# %%
df_append = df_append [[
    'id',
    'sectionName',
    'webPublicationDate',
    'webPublicationDateTime',
    'webTitle',
    'pillarId',
    'pillarName'
]]

# %%
df_append
# Out:
#                                                        id         sectionName  \
# 0       money/2018/jan/01/protests-planned-uk-rail-sta...               Money
# 1       crosswords/2018/jan/01/annotated-solutions-for...          Crosswords
# 2          crosswords/2018/jan/01/genius-crossword-no-175          Crosswords
# 3       education/2018/jan/01/toby-young-universities-...           Education
# 4       uk-news/2018/jan/01/prince-of-wales-charitable...             UK news
# ...                                                   ...                 ...
# 365653  world/2022/nov/13/mines-looting-no-power-khers...          World news
# 365654  sport/2022/nov/13/russell-admits-tears-were-fl...               Sport
# 365655  uk-news/2022/nov/13/joe-biden-to-meet-rishi-su...             UK news
# 365656  uk-news/2022/nov/13/sunak-says-higher-taxes-an...             UK news
# 365657  tv-and-radio/2022/nov/13/young-black-and-right...  Television & radio
#
#        webPublicationDate webPublicationDateTime  \
# 0              2018-01-01   2018-01-01T00:01:11Z
# 1              2018-01-01   2018-01-01T00:01:11Z
# 2              2018-01-01   2018-01-01T00:01:11Z
# 3              2018-01-01   2018-01-01T00:01:12Z
# 4              2018-01-01   2018-01-01T00:39:36Z
# ...                   ...                    ...
# 365653         2022-11-13   2022-11-13T22:19:22Z
# 365654         2022-11-13   2022-11-13T22:23:14Z
# 365655         2022-11-13   2022-11-13T22:30:22Z
# 365656         2022-11-13   2022-11-13T22:30:22Z
# 365657         2022-11-13   2022-11-13T22:55:22Z
#
#                                                  webTitle          pillarId  \
# 0       Protests planned at UK rail stations to mark s...  pillar/lifestyle
# 1                      Annotated solutions for Genius 174  pillar/lifestyle
# 2                                 Genius crossword No 175  pillar/lifestyle
# 3       Toby Young to help lead government's new unive...       pillar/news
# 4       Prince of Wales Charitable Foundation halves d...       pillar/news
# ...                                                   ...               ...
# 365653     Zelenskiy accuses Russia of Kherson war crimes       pillar/news
# 365654  Russell admits ‘tears were flooding’ after emo...      pillar/sport
# 365655  Biden to meet Sunak as pressure grows on PM ov...       pillar/news
# 365656  Sunak says higher taxes and spending cuts need...       pillar/news
# 365657  Young, Black and Right-Wing review – you’ll ne...       pillar/arts
#
#        pillarName
# 0       Lifestyle
# 1       Lifestyle
# 2       Lifestyle
# 3            News
# 4            News
# ...           ...
# 365653       News
# 365654      Sport
# 365655       News
# 365656       News
# 365657       Arts
#
# [365658 rows x 7 columns]

# %%
df_append.to_csv('guardian-article-data_general.csv',index=False,sep=';')

# %% [markdown]
# ## Uniting files from `tags` directory

# %%
#read the path
file_path = 'tags'

# %%
#list all the files from the directory
file_list = os.listdir(file_path)
file_list
# Out:
# ['guardian-article-data_start-date-2018-01-01_end-date-2018-03-31_tags.csv',
#  'guardian-article-data_start-date-2018-04-01_end-date-2018-06-30_tags.csv',
#  'guardian-article-data_start-date-2018-07-01_end-date-2018-12-31_tags.csv',
#  'guardian-article-data_start-date-2019-01-01_end-date-2019-06-30_tags.csv',
#  'guardian-article-data_start-date-2019-07-01_end-date-2019-12-31_tags.csv',
#  'guardian-article-data_start-date-2020-01-01_end-date-2020-03-31_tags.csv',
#  'guardian-article-data_start-date-2020-04-01_end-date-2020-06-30_tags.csv',
#  'guardian-article-data_start-date-2020-07-01_end-date-2020-12-31_tags.csv',
#  'guardian-article-data_start-date-2021-01-01_end-date-2021-06-30_tags.csv',
#  'guardian-article-data_start-date-2021-07-01_end-date-2021-12-31_tags.csv',
#  'guardian-article-data_start-date-2022-01-01_end-date-2022-06-30_tags.csv',
#  'guardian-article-data_start-date-2022-07-01_end-date-2022-11-11_tags.csv',
#  'guardian-article-data_start-date-2022-11-12_end-date-2022-11-13_tags.csv']

# %%
csv_files = glob.glob('{}/*{}.{}'.format('tags','_tags','csv'))
csv_files
# Out:
# ['tags\\guardian-article-data_start-date-2018-01-01_end-date-2018-03-31_tags.csv',
#  'tags\\guardian-article-data_start-date-2018-04-01_end-date-2018-06-30_tags.csv',
#  'tags\\guardian-article-data_start-date-2018-07-01_end-date-2018-12-31_tags.csv',
#  'tags\\guardian-article-data_start-date-2019-01-01_end-date-2019-06-30_tags.csv',
#  'tags\\guardian-article-data_start-date-2019-07-01_end-date-2019-12-31_tags.csv',
#  'tags\\guardian-article-data_start-date-2020-01-01_end-date-2020-03-31_tags.csv',
#  'tags\\guardian-article-data_start-date-2020-04-01_end-date-2020-06-30_tags.csv',
#  'tags\\guardian-article-data_start-date-2020-07-01_end-date-2020-12-31_tags.csv',
#  'tags\\guardian-article-data_start-date-2021-01-01_end-date-2021-06-30_tags.csv',
#  'tags\\guardian-article-data_start-date-2021-07-01_end-date-2021-12-31_tags.csv',
#  'tags\\guardian-article-data_start-date-2022-01-01_end-date-2022-06-30_tags.csv',
#  'tags\\guardian-article-data_start-date-2022-07-01_end-date-2022-11-11_tags.csv',
#  'tags\\guardian-article-data_start-date-2022-11-12_end-date-2022-11-13_tags.csv']

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file,sep=';')
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\borar\AppData\Local\Temp\ipykernel_13208\3375644103.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
#          id_num                                                 id  \
# 0             1  money/2018/jan/01/protests-planned-uk-rail-sta...
# 1             1  money/2018/jan/01/protests-planned-uk-rail-sta...
# 2             1  money/2018/jan/01/protests-planned-uk-rail-sta...
# 3             1  money/2018/jan/01/protests-planned-uk-rail-sta...
# 4             1  money/2018/jan/01/protests-planned-uk-rail-sta...
# ...         ...                                                ...
# 2275899     315  uk-news/2022/nov/13/sunak-says-higher-taxes-an...
# 2275900     315  uk-news/2022/nov/13/sunak-says-higher-taxes-an...
# 2275901     316  tv-and-radio/2022/nov/13/young-black-and-right...
# 2275902     316  tv-and-radio/2022/nov/13/young-black-and-right...
# 2275903     316  tv-and-radio/2022/nov/13/young-black-and-right...
#
#                             tag_id     tag_sectionName        tag_webTitle  \
# 0                 money/rail-fares               Money          Rail fares
# 1                uk/rail-transport             UK news      Rail transport
# 2                     uk/transport             UK news           Transport
# 3               politics/transport            Politics    Transport policy
# 4           money/consumer-affairs               Money    Consumer affairs
# ...                            ...                 ...                 ...
# 2275899                  world/g20          World news                 G20
# 2275900          politics/politics            Politics            Politics
# 2275901         culture/television  Television & radio          Television
# 2275902  tv-and-radio/tv-and-radio  Television & radio  Television & radio
# 2275903            culture/culture             Culture             Culture
#
#         tag_description
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 2275899             NaN
# 2275900     <p><br></p>
# 2275901             NaN
# 2275902             NaN
# 2275903             NaN
#
# [2275904 rows x 6 columns]

# %%
df_append = df_append [[
    'id',
    'tag_id',
    'tag_sectionName',
    'tag_webTitle'
]]

# %%
df_append
# Out:
#                                                         id  \
# 0        money/2018/jan/01/protests-planned-uk-rail-sta...
# 1        money/2018/jan/01/protests-planned-uk-rail-sta...
# 2        money/2018/jan/01/protests-planned-uk-rail-sta...
# 3        money/2018/jan/01/protests-planned-uk-rail-sta...
# 4        money/2018/jan/01/protests-planned-uk-rail-sta...
# ...                                                    ...
# 2275899  uk-news/2022/nov/13/sunak-says-higher-taxes-an...
# 2275900  uk-news/2022/nov/13/sunak-says-higher-taxes-an...
# 2275901  tv-and-radio/2022/nov/13/young-black-and-right...
# 2275902  tv-and-radio/2022/nov/13/young-black-and-right...
# 2275903  tv-and-radio/2022/nov/13/young-black-and-right...
#
#                             tag_id     tag_sectionName        tag_webTitle
# 0                 money/rail-fares               Money          Rail fares
# 1                uk/rail-transport             UK news      Rail transport
# 2                     uk/transport             UK news           Transport
# 3               politics/transport            Politics    Transport policy
# 4           money/consumer-affairs               Money    Consumer affairs
# ...                            ...                 ...                 ...
# 2275899                  world/g20          World news                 G20
# 2275900          politics/politics            Politics            Politics
# 2275901         culture/television  Television & radio          Television
# 2275902  tv-and-radio/tv-and-radio  Television & radio  Television & radio
# 2275903            culture/culture             Culture             Culture
#
# [2275904 rows x 4 columns]

# %%
df_append.to_csv('guardian-article-data_tags.csv',index=False,sep=';')

# %% [markdown]
# # Load data about articles from the Guardian Media Group API

# %% [markdown]
# ## 1. Extract information using the Guardian Media Group API

# %% [markdown]
# More information about using the Guardian Media Group API can be found in [Documentation](https://open-platform.theguardian.com/documentation/)

# %% [markdown]
# To access the API, it is needed to [sign up for anAPI key](https://open-platform.theguardian.com/access/), which should be sent with every request.

# %% [markdown]
# I generated an API key and saved it in api.cfg file.

# %% [markdown]
# Import required libraries:

# %%
import configparser
import json
from datetime import datetime, timedelta, date

# %%
import requests

# %%
import pandas as pd

# %% [markdown]
# Import API key:

# %%
config =  configparser.ConfigParser()
config.read('api.cfg')
# Out:
# ['api.cfg']

# %% [markdown]
# Create query for extracting data from the Guardian Media Group API, which extacts data from 2021-01-01 to today:

# %%
from_date = '2022-11-12'
to_date = '2022-11-13'

# %%
url_querry = 'https://content.guardianapis.com/search?' \
    + 'api-key=' + config['API']['KEY'] + '&' \
    + 'from-date=' + from_date + '&' \
    + 'to-date=' + to_date + '&' \
    + 'type=' + 'article' + '&' \
    + 'show-tags=keyword' + '&' \
    + 'order-by=' + 'oldest'

# %% [markdown]
# Get response from API and save as JSON object.

# %%
response = requests.get(url_querry)
data_json = response.json()

# %% [markdown]
# Get number of pages of query:

# %%
# could be max only 3800
data_json['response']['pages']
# Out:
# 32

# %%
data_json['response']
# Out:
# {'status': 'ok',
#  'userTier': 'developer',
#  'total': 316,
#  'startIndex': 1,
#  'pageSize': 10,
#  'currentPage': 1,
#  'pages': 32,
#  'orderBy': 'oldest',
#  'results': [{'id': 'football/2022/nov/12/harry-kane-world-cup-fitness-england-tottenham-antonio-conte',
#    'type': 'article',
#    'sectionId': 'football',
#    'sectionName': 'Football',
#    'webPublicationDate': '2022-11-12T00:04:24Z',
#    'webTitle': 'England fans ‘must not worry’ about Harry Kane’s fitness, insists Conte',
#    'webUrl': 'https://www.theguardian.com/football/2022/nov/12/harry-kane-world-cup-fitness-england-tottenham-antonio-conte',
#    'apiUrl': 'https://content.guardianapis.com/football/2022/nov/12/harry-kane-world-cup-fitness-england-tottenham-antonio-conte',
#    'tags': [{'id': 'football/harry-kane',
#      'type': 'keyword',
#      'sectionId': 'football',
#      'sectionName': 'Football',
#      'webTitle': 'Harry Kane',
#      'webUrl': 'https://www.theguardian.com/football/harry-kane',
#      'apiUrl': 'https://content.guardianapis.com/football/harry-kane',
#      'references': []},
#     {'id': 'football/world-cup-2022',
#      'type': 'keyword',
#      'sectionId': 'football',
#      'sectionName': 'Football',
#      'webTitle': 'World Cup 2022',
#      'webUrl': 'https://www.theguardian.com/football/world-cup-2022',
#      'apiUrl': 'https://content.guardianapis.com/football/world-cup-2022',
#      'references': []},
#     {'id': 'football/england',
#      'type': 'keyword',
#      'sectionId': 'football',
#      'sectionName': 'Football',
#      'webTitle': 'England',
#      'webUrl': 'https://www.theguardian.com/football/england',
#      'apiUrl': 'https://content.guardianapis.com/football/england',
#      'references': []},
#     {'id': 'football/tottenham-hotspur',
#      'type': 'keyword',
#      'sectionId': 'football',
#      'sectionName': 'Football',
#      'webTitle': 'Tottenham Hotspur',
#      'webUrl': 'https://www.theguardian.com/football/tottenham-hotspur',
#      'apiUrl': 'https://content.guardianapis.com/football/tottenham-hotspur',
#      'references': [],
#      'description': 'Read the latest Tottenham Hotspur news, transfer rumours, match reports, fixtures and live scores from the Guardian'},
#     {'id': 'football/football',
#      'type': 'keyword',
#      'sectionId': 'football',
#      'sectionName': 'Football',
#      'webTitle': 'Football',
#      'webUrl': 'https://www.theguardian.com/football/football',
#      'apiUrl': 'https://content.guardianapis.com/football/football',
#      'references': []},
#     {'id': 'sport/sport',
#      'type': 'keyword',
#      'sectionId': 'sport',
#      'sectionName': 'Sport',
#      'webTitle': 'Sport',
#      'webUrl': 'https://www.theguardian.com/sport/sport',
#      'apiUrl': 'https://content.guardianapis.com/sport/sport',
#      'references': []},
#     {'id': 'football/antonio-conte',
#      'type': 'keyword',
#      'sectionId': 'football',
#      'sectionName': 'Football',
#      'webTitle': 'Antonio Conte',
#      'webUrl': 'https://www.theguardian.com/football/antonio-conte',
#      'apiUrl': 'https://content.guardianapis.com/football/antonio-conte',
#      'references': []}],
#    'isHosted': False,
#    'pillarId': 'pillar/sport',
#    'pillarName': 'Sport'},
#   {'id': 'australia-news/2022/nov/11/cruise-ship-majestic-princess-to-dock-in-sydney-with-800-covid-cases-on-board',
#    'type': 'article',
#    'sectionId': 'australia-news',
#    'sectionName': 'Australia news',
#    'webPublicationDate': '2022-11-12T00:35:40Z',
#    'webTitle': 'Majestic Princess: cruise ship passengers disembark in Sydney after mass Covid outbreak',
#    'webUrl': 'https://www.theguardian.com/australia-news/2022/nov/11/cruise-ship-majestic-princess-to-dock-in-sydney-with-800-covid-cases-on-board',
#    'apiUrl': 'https://content.guardianapis.com/australia-news/2022/nov/11/cruise-ship-majestic-princess-to-dock-in-sydney-with-800-covid-cases-on-board',
#    'tags': [{'id': 'australia-news/australia-news',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'Australia news',
#      'webUrl': 'https://www.theguardian.com/australia-news/australia-news',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/australia-news',
#      'references': []},
#     {'id': 'world/coronavirus-outbreak',
#      'type': 'keyword',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webTitle': 'Coronavirus',
#      'webUrl': 'https://www.theguardian.com/world/coronavirus-outbreak',
#      'apiUrl': 'https://content.guardianapis.com/world/coronavirus-outbreak',
#      'references': []},
#     {'id': 'australia-news/new-south-wales',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'New South Wales',
#      'webUrl': 'https://www.theguardian.com/australia-news/new-south-wales',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/new-south-wales',
#      'references': [],
#      'description': 'Latest news and comment on the Australian state of New South Wales'},
#     {'id': 'australia-news/sydney',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'Sydney',
#      'webUrl': 'https://www.theguardian.com/australia-news/sydney',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/sydney',
#      'references': [],
#      'description': 'Latest news and comment on Sydney'},
#     {'id': 'travel/cruises',
#      'type': 'keyword',
#      'sectionId': 'travel',
#      'sectionName': 'Travel',
#      'webTitle': 'Cruises',
#      'webUrl': 'https://www.theguardian.com/travel/cruises',
#      'apiUrl': 'https://content.guardianapis.com/travel/cruises',
#      'references': []},
#     {'id': 'australia-news/health',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'Health',
#      'webUrl': 'https://www.theguardian.com/australia-news/health',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/health',
#      'references': []}],
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2022/nov/11/democrat-mark-kelly-arizona-senate-blake-masters',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2022-11-12T03:46:54Z',
#    'webTitle': 'Mark Kelly holds on to Arizona seat in critical win for Democrats',
#    'webUrl': 'https://www.theguardian.com/us-news/2022/nov/11/democrat-mark-kelly-arizona-senate-blake-masters',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2022/nov/11/democrat-mark-kelly-arizona-senate-blake-masters',
#    'tags': [{'id': 'us-news/us-midterm-elections-2022',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'US midterm elections 2022',
#      'webUrl': 'https://www.theguardian.com/us-news/us-midterm-elections-2022',
#      'apiUrl': 'https://content.guardianapis.com/us-news/us-midterm-elections-2022',
#      'references': []},
#     {'id': 'us-news/arizona',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'Arizona',
#      'webUrl': 'https://www.theguardian.com/us-news/arizona',
#      'apiUrl': 'https://content.guardianapis.com/us-news/arizona',
#      'references': []},
#     {'id': 'us-news/us-senate',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'US Senate',
#      'webUrl': 'https://www.theguardian.com/us-news/us-senate',
#      'apiUrl': 'https://content.guardianapis.com/us-news/us-senate',
#      'references': []},
#     {'id': 'us-news/republicans',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'Republicans',
#      'webUrl': 'https://www.theguardian.com/us-news/republicans',
#      'apiUrl': 'https://content.guardianapis.com/us-news/republicans',
#      'references': []},
#     {'id': 'us-news/democrats',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'Democrats',
#      'webUrl': 'https://www.theguardian.com/us-news/democrats',
#      'apiUrl': 'https://content.guardianapis.com/us-news/democrats',
#      'references': []},
#     {'id': 'us-news/us-news',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'US news',
#      'webUrl': 'https://www.theguardian.com/us-news/us-news',
#      'apiUrl': 'https://content.guardianapis.com/us-news/us-news',
#      'references': []}],
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'australia-news/2022/nov/12/medibank-hack-clare-oneil-says-new-cybercrime-operation-will-hunt-down-russian-thugs',
#    'type': 'article',
#    'sectionId': 'australia-news',
#    'sectionName': 'Australia news',
#    'webPublicationDate': '2022-11-12T03:47:17Z',
#    'webTitle': 'Medibank hack: Clare O’Neil says new cybercrime operation will hunt down ‘Russian thugs’',
#    'webUrl': 'https://www.theguardian.com/australia-news/2022/nov/12/medibank-hack-clare-oneil-says-new-cybercrime-operation-will-hunt-down-russian-thugs',
#    'apiUrl': 'https://content.guardianapis.com/australia-news/2022/nov/12/medibank-hack-clare-oneil-says-new-cybercrime-operation-will-hunt-down-russian-thugs',
#    'tags': [{'id': 'australia-news/australian-politics',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'Australian politics',
#      'webUrl': 'https://www.theguardian.com/australia-news/australian-politics',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/australian-politics',
#      'references': []},
#     {'id': 'australia-news/labor-party',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'Labor party',
#      'webUrl': 'https://www.theguardian.com/australia-news/labor-party',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/labor-party',
#      'references': []},
#     {'id': 'australia-news/coalition',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'Coalition',
#      'webUrl': 'https://www.theguardian.com/australia-news/coalition',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/coalition',
#      'references': []},
#     {'id': 'australia-news/australia-news',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'Australia news',
#      'webUrl': 'https://www.theguardian.com/australia-news/australia-news',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/australia-news',
#      'references': []},
#     {'id': 'world/russia',
#      'type': 'keyword',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webTitle': 'Russia',
#      'webUrl': 'https://www.theguardian.com/world/russia',
#      'apiUrl': 'https://content.guardianapis.com/world/russia',
#      'references': []},
#     {'id': 'australia-news/medibank',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'Medibank',
#      'webUrl': 'https://www.theguardian.com/australia-news/medibank',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/medibank',
#      'references': []},
#     {'id': 'australia-news/crime-australia',
#      'type': 'keyword',
#      'sectionId': 'australia-news',
#      'sectionName': 'Australia news',
#      'webTitle': 'Crime - Australia',
#      'webUrl': 'https://www.theguardian.com/australia-news/crime-australia',
#      'apiUrl': 'https://content.guardianapis.com/australia-news/crime-australia',
#      'references': [],
#      'description': 'Latest news on crime in Australia from the Guardian'}],
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'environment/2022/nov/12/replace-animal-farms-micro-organism-rewilding-food-precision-fermentation-emissions',
#    'type': 'article',
#    'sectionId': 'environment',
#    'sectionName': 'Environment',
#    'webPublicationDate': '2022-11-12T04:00:30Z',
#    'webTitle': 'Replace animal farms with micro-organism tanks, say campaigners',
#    'webUrl': 'https://www.theguardian.com/environment/2022/nov/12/replace-animal-farms-micro-organism-rewilding-food-precision-fermentation-emissions',
#    'apiUrl': 'https://content.guardianapis.com/environment/2022/nov/12/replace-animal-farms-micro-organism-rewilding-food-precision-fermentation-emissions',
#    'tags': [{'id': 'environment/food',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Food',
#      'webUrl': 'https://www.theguardian.com/environment/food',
#      'apiUrl': 'https://content.guardianapis.com/environment/food',
#      'references': []},
#     {'id': 'environment/meat-industry',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Meat industry',
#      'webUrl': 'https://www.theguardian.com/environment/meat-industry',
#      'apiUrl': 'https://content.guardianapis.com/environment/meat-industry',
#      'references': []},
#     {'id': 'environment/farming',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Farming',
#      'webUrl': 'https://www.theguardian.com/environment/farming',
#      'apiUrl': 'https://content.guardianapis.com/environment/farming',
#      'references': []},
#     {'id': 'environment/farm-animals',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Farm animals',
#      'webUrl': 'https://www.theguardian.com/environment/farm-animals',
#      'apiUrl': 'https://content.guardianapis.com/environment/farm-animals',
#      'references': []},
#     {'id': 'environment/carbon-emissions',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Greenhouse gas emissions',
#      'webUrl': 'https://www.theguardian.com/environment/carbon-emissions',
#      'apiUrl': 'https://content.guardianapis.com/environment/carbon-emissions',
#      'references': []},
#     {'id': 'environment/environment',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Environment',
#      'webUrl': 'https://www.theguardian.com/environment/environment',
#      'apiUrl': 'https://content.guardianapis.com/environment/environment',
#      'references': []},
#     {'id': 'world/animals',
#      'type': 'keyword',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webTitle': 'Animals',
#      'webUrl': 'https://www.theguardian.com/world/animals',
#      'apiUrl': 'https://content.guardianapis.com/world/animals',
#      'references': []},
#     {'id': 'science/food-science',
#      'type': 'keyword',
#      'sectionId': 'science',
#      'sectionName': 'Science',
#      'webTitle': 'Food science',
#      'webUrl': 'https://www.theguardian.com/science/food-science',
#      'apiUrl': 'https://content.guardianapis.com/science/food-science',
#      'references': []},
#     {'id': 'business/fooddrinks',
#      'type': 'keyword',
#      'sectionId': 'business',
#      'sectionName': 'Business',
#      'webTitle': 'Food & drink industry',
#      'webUrl': 'https://www.theguardian.com/business/fooddrinks',
#      'apiUrl': 'https://content.guardianapis.com/business/fooddrinks',
#      'references': []},
#     {'id': 'food/food',
#      'type': 'keyword',
#      'webTitle': 'Food',
#      'webUrl': 'https://www.theguardian.com/food/food',
#      'apiUrl': 'https://content.guardianapis.com/food/food',
#      'references': []},
#     {'id': 'uk/uk',
#      'type': 'keyword',
#      'sectionId': 'uk-news',
#      'sectionName': 'UK news',
#      'webTitle': 'UK news',
#      'webUrl': 'https://www.theguardian.com/uk/uk',
#      'apiUrl': 'https://content.guardianapis.com/uk/uk',
#      'references': []},
#     {'id': 'environment/cop27',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Cop27',
#      'webUrl': 'https://www.theguardian.com/environment/cop27',
#      'apiUrl': 'https://content.guardianapis.com/environment/cop27',
#      'references': []}],
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2022/nov/12/arizona-secretary-of-state-election-winnner-adrian-fontes',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2022-11-12T04:14:17Z',
#    'webTitle': 'Adrian Fontes wins highly contested secretary of state in Arizona',
#    'webUrl': 'https://www.theguardian.com/us-news/2022/nov/12/arizona-secretary-of-state-election-winnner-adrian-fontes',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2022/nov/12/arizona-secretary-of-state-election-winnner-adrian-fontes',
#    'tags': [{'id': 'us-news/arizona',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'Arizona',
#      'webUrl': 'https://www.theguardian.com/us-news/arizona',
#      'apiUrl': 'https://content.guardianapis.com/us-news/arizona',
#      'references': []},
#     {'id': 'us-news/us-news',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'US news',
#      'webUrl': 'https://www.theguardian.com/us-news/us-news',
#      'apiUrl': 'https://content.guardianapis.com/us-news/us-news',
#      'references': []},
#     {'id': 'us-news/us-midterm-elections-2022',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'US midterm elections 2022',
#      'webUrl': 'https://www.theguardian.com/us-news/us-midterm-elections-2022',
#      'apiUrl': 'https://content.guardianapis.com/us-news/us-midterm-elections-2022',
#      'references': []},
#     {'id': 'world/far-right',
#      'type': 'keyword',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webTitle': 'The far right',
#      'webUrl': 'https://www.theguardian.com/world/far-right',
#      'apiUrl': 'https://content.guardianapis.com/world/far-right',
#      'references': []},
#     {'id': 'us-news/us-capitol-breach',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'US Capitol attack',
#      'webUrl': 'https://www.theguardian.com/us-news/us-capitol-breach',
#      'apiUrl': 'https://content.guardianapis.com/us-news/us-capitol-breach',
#      'references': []}],
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'environment/2022/nov/12/country-diary-the-serious-business-of-a-herdwick-meet',
#    'type': 'article',
#    'sectionId': 'environment',
#    'sectionName': 'Environment',
#    'webPublicationDate': '2022-11-12T05:30:31Z',
#    'webTitle': 'Country diary: The serious business of a Herdwick meet',
#    'webUrl': 'https://www.theguardian.com/environment/2022/nov/12/country-diary-the-serious-business-of-a-herdwick-meet',
#    'apiUrl': 'https://content.guardianapis.com/environment/2022/nov/12/country-diary-the-serious-business-of-a-herdwick-meet',
#    'tags': [{'id': 'environment/farm-animals',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Farm animals',
#      'webUrl': 'https://www.theguardian.com/environment/farm-animals',
#      'apiUrl': 'https://content.guardianapis.com/environment/farm-animals',
#      'references': []},
#     {'id': 'environment/farming',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Farming',
#      'webUrl': 'https://www.theguardian.com/environment/farming',
#      'apiUrl': 'https://content.guardianapis.com/environment/farming',
#      'references': []},
#     {'id': 'environment/environment',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Environment',
#      'webUrl': 'https://www.theguardian.com/environment/environment',
#      'apiUrl': 'https://content.guardianapis.com/environment/environment',
#      'references': []},
#     {'id': 'uk/ruralaffairs',
#      'type': 'keyword',
#      'sectionId': 'uk-news',
#      'sectionName': 'UK news',
#      'webTitle': 'Rural affairs',
#      'webUrl': 'https://www.theguardian.com/uk/ruralaffairs',
#      'apiUrl': 'https://content.guardianapis.com/uk/ruralaffairs',
#      'references': []},
#     {'id': 'uk/uk',
#      'type': 'keyword',
#      'sectionId': 'uk-news',
#      'sectionName': 'UK news',
#      'webTitle': 'UK news',
#      'webUrl': 'https://www.theguardian.com/uk/uk',
#      'apiUrl': 'https://content.guardianapis.com/uk/uk',
#      'references': []}],
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'culture/2022/nov/12/from-haiti-to-redcar-a-complete-guide-to-this-weeks-entertainment',
#    'type': 'article',
#    'sectionId': 'culture',
#    'sectionName': 'Culture',
#    'webPublicationDate': '2022-11-12T06:00:32Z',
#    'webTitle': 'From Haiti to Redcar: a complete guide to this week’s entertainment ',
#    'webUrl': 'https://www.theguardian.com/culture/2022/nov/12/from-haiti-to-redcar-a-complete-guide-to-this-weeks-entertainment',
#    'apiUrl': 'https://content.guardianapis.com/culture/2022/nov/12/from-haiti-to-redcar-a-complete-guide-to-this-weeks-entertainment',
#    'tags': [{'id': 'culture/culture',
#      'type': 'keyword',
#      'sectionId': 'culture',
#      'sectionName': 'Culture',
#      'webTitle': 'Culture',
#      'webUrl': 'https://www.theguardian.com/culture/culture',
#      'apiUrl': 'https://content.guardianapis.com/culture/culture',
#      'references': []},
#     {'id': 'music/music',
#      'type': 'keyword',
#      'sectionId': 'music',
#      'sectionName': 'Music',
#      'webTitle': 'Music',
#      'webUrl': 'https://www.theguardian.com/music/music',
#      'apiUrl': 'https://content.guardianapis.com/music/music',
#      'references': []},
#     {'id': 'stage/stage',
#      'type': 'keyword',
#      'sectionId': 'stage',
#      'sectionName': 'Stage',
#      'webTitle': 'Stage',
#      'webUrl': 'https://www.theguardian.com/stage/stage',
#      'apiUrl': 'https://content.guardianapis.com/stage/stage',
#      'references': []},
#     {'id': 'stage/dance',
#      'type': 'keyword',
#      'sectionId': 'stage',
#      'sectionName': 'Stage',
#      'webTitle': 'Dance',
#      'webUrl': 'https://www.theguardian.com/stage/dance',
#      'apiUrl': 'https://content.guardianapis.com/stage/dance',
#      'references': []},
#     {'id': 'stage/theatre',
#      'type': 'keyword',
#      'sectionId': 'stage',
#      'sectionName': 'Stage',
#      'webTitle': 'Theatre',
#      'webUrl': 'https://www.theguardian.com/stage/theatre',
#      'apiUrl': 'https://content.guardianapis.com/stage/theatre',
#      'references': []},
#     {'id': 'film/film',
#      'type': 'keyword',
#      'sectionId': 'film',
#      'sectionName': 'Film',
#      'webTitle': 'Film',
#      'webUrl': 'https://www.theguardian.com/film/film',
#      'apiUrl': 'https://content.guardianapis.com/film/film',
#      'references': []},
#     {'id': 'culture/television',
#      'type': 'keyword',
#      'sectionId': 'tv-and-radio',
#      'sectionName': 'Television & radio',
#      'webTitle': 'Television',
#      'webUrl': 'https://www.theguardian.com/culture/television',
#      'apiUrl': 'https://content.guardianapis.com/culture/television',
#      'references': []},
#     {'id': 'tv-and-radio/tv-and-radio',
#      'type': 'keyword',
#      'sectionId': 'tv-and-radio',
#      'sectionName': 'Television & radio',
#      'webTitle': 'Television & radio',
#      'webUrl': 'https://www.theguardian.com/tv-and-radio/tv-and-radio',
#      'apiUrl': 'https://content.guardianapis.com/tv-and-radio/tv-and-radio',
#      'references': []},
#     {'id': 'artanddesign/art',
#      'type': 'keyword',
#      'sectionId': 'artanddesign',
#      'sectionName': 'Art and design',
#      'webTitle': 'Art',
#      'webUrl': 'https://www.theguardian.com/artanddesign/art',
#      'apiUrl': 'https://content.guardianapis.com/artanddesign/art',
#      'references': []},
#     {'id': 'artanddesign/artanddesign',
#      'type': 'keyword',
#      'sectionId': 'artanddesign',
#      'sectionName': 'Art and design',
#      'webTitle': 'Art and design',
#      'webUrl': 'https://www.theguardian.com/artanddesign/artanddesign',
#      'apiUrl': 'https://content.guardianapis.com/artanddesign/artanddesign',
#      'references': []},
#     {'id': 'games/games',
#      'type': 'keyword',
#      'webTitle': 'Games',
#      'webUrl': 'https://www.theguardian.com/games/games',
#      'apiUrl': 'https://content.guardianapis.com/games/games',
#      'references': []}],
#    'isHosted': False,
#    'pillarId': 'pillar/arts',
#    'pillarName': 'Arts'},
#   {'id': 'us-news/2022/nov/12/weather-tracker-unusual-cold-and-snow-spreading-across-north-america',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2022-11-12T06:00:32Z',
#    'webTitle': 'Weather tracker: unusual cold and snow spreading across North America',
#    'webUrl': 'https://www.theguardian.com/us-news/2022/nov/12/weather-tracker-unusual-cold-and-snow-spreading-across-north-america',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2022/nov/12/weather-tracker-unusual-cold-and-snow-spreading-across-north-america',
#    'tags': [{'id': 'us-news/us-weather',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'US weather',
#      'webUrl': 'https://www.theguardian.com/us-news/us-weather',
#      'apiUrl': 'https://content.guardianapis.com/us-news/us-weather',
#      'references': []},
#     {'id': 'us-news/us-news',
#      'type': 'keyword',
#      'sectionId': 'us-news',
#      'sectionName': 'US news',
#      'webTitle': 'US news',
#      'webUrl': 'https://www.theguardian.com/us-news/us-news',
#      'apiUrl': 'https://content.guardianapis.com/us-news/us-news',
#      'references': []},
#     {'id': 'world/canada',
#      'type': 'keyword',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webTitle': 'Canada',
#      'webUrl': 'https://www.theguardian.com/world/canada',
#      'apiUrl': 'https://content.guardianapis.com/world/canada',
#      'references': []},
#     {'id': 'world/americas',
#      'type': 'keyword',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webTitle': 'Americas',
#      'webUrl': 'https://www.theguardian.com/world/americas',
#      'apiUrl': 'https://content.guardianapis.com/world/americas',
#      'references': []},
#     {'id': 'environment/environment',
#      'type': 'keyword',
#      'sectionId': 'environment',
#      'sectionName': 'Environment',
#      'webTitle': 'Environment',
#      'webUrl': 'https://www.theguardian.com/environment/environment',
#      'apiUrl': 'https://content.guardianapis.com/environment/environment',
#      'references': []},
#     {'id': 'world/extreme-weather',
#      'type': 'keyword',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webTitle': 'Extreme weather',
#      'webUrl': 'https://www.theguardian.com/world/extreme-weather',
#      'apiUrl': 'https://content.guardianapis.com/world/extreme-weather',
#      'references': []},
#     {'id': 'world/world',
#      'type': 'keyword',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webTitle': 'World news',
#      'webUrl': 'https://www.theguardian.com/world/world',
#      'apiUrl': 'https://content.guardianapis.com/world/world',
#      'references': []},
#     {'id': 'world/portugal',
#      'type': 'keyword',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webTitle': 'Portugal',
#      'webUrl': 'https://www.theguardian.com/world/portugal',
#      'apiUrl': 'https://content.guardianapis.com/world/portugal',
#      'references': []},
#     {'id': 'weather/portugal',
#      'type': 'keyword',
#      'sectionId': 'weather',
#      'sectionName': 'Weather',
#      'webTitle': 'Portugal',
#      'webUrl': 'https://www.theguardian.com/weather/portugal',
#      'apiUrl': 'https://content.guardianapis.com/weather/portugal',
#      'references': []}],
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'politics/2022/nov/12/autumn-statement-which-tax-rises-and-spending-cuts-are-most-likely',
#    'type': 'article',
#    'sectionId': 'politics',
#    'sectionName': 'Politics',
#    'webPublicationDate': '2022-11-12T06:00:33Z',
#    'webTitle': 'Autumn statement: which tax rises and spending cuts are most likely?',
#    'webUrl': 'https://www.theguardian.com/politics/2022/nov/12/autumn-statement-which-tax-rises-and-spending-cuts-are-most-likely',
#    'apiUrl': 'https://content.guardianapis.com/politics/2022/nov/12/autumn-statement-which-tax-rises-and-spending-cuts-are-most-likely',
#    'tags': [{'id': 'politics/economy',
#      'type': 'keyword',
#      'sectionId': 'politics',
#      'sectionName': 'Politics',
#      'webTitle': 'Economic policy',
#      'webUrl': 'https://www.theguardian.com/politics/economy',
#      'apiUrl': 'https://content.guardianapis.com/politics/economy',
#      'references': []},
#     {'id': 'politics/rishi-sunak',
#      'type': 'keyword',
#      'sectionId': 'politics',
#      'sectionName': 'Politics',
#      'webTitle': 'Rishi Sunak',
#      'webUrl': 'https://www.theguardian.com/politics/rishi-sunak',
#      'apiUrl': 'https://content.guardianapis.com/politics/rishi-sunak',
#      'references': []},
#     {'id': 'politics/jeremy-hunt',
#      'type': 'keyword',
#      'sectionId': 'politics',
#      'sectionName': 'Politics',
#      'webTitle': 'Jeremy Hunt',
#      'webUrl': 'https://www.theguardian.com/politics/jeremy-hunt',
#      'apiUrl': 'https://content.guardianapis.com/politics/jeremy-hunt',
#      'references': []},
#     {'id': 'politics/conservatives',
#      'type': 'keyword',
#      'sectionId': 'politics',
#      'sectionName': 'Politics',
#      'webTitle': 'Conservatives',
#      'webUrl': 'https://www.theguardian.com/politics/conservatives',
#      'apiUrl': 'https://content.guardianapis.com/politics/conservatives',
#      'references': []},
#     {'id': 'politics/taxandspending',
#      'type': 'keyword',
#      'sectionId': 'politics',
#      'sectionName': 'Politics',
#      'webTitle': 'Tax and spending',
#      'webUrl': 'https://www.theguardian.com/politics/taxandspending',
#      'apiUrl': 'https://content.guardianapis.com/politics/taxandspending',
#      'references': []},
#     {'id': 'politics/welfare',
#      'type': 'keyword',
#      'sectionId': 'politics',
#      'sectionName': 'Politics',
#      'webTitle': 'Welfare',
#      'webUrl': 'https://www.theguardian.com/politics/welfare',
#      'apiUrl': 'https://content.guardianapis.com/politics/welfare',
#      'references': []},
#     {'id': 'money/tax',
#      'type': 'keyword',
#      'sectionId': 'money',
#      'sectionName': 'Money',
#      'webTitle': 'Tax',
#      'webUrl': 'https://www.theguardian.com/money/tax',
#      'apiUrl': 'https://content.guardianapis.com/money/tax',
#      'references': []},
#     {'id': 'money/pensions',
#      'type': 'keyword',
#      'sectionId': 'money',
#      'sectionName': 'Money',
#      'webTitle': 'Pensions',
#      'webUrl': 'https://www.theguardian.com/money/pensions',
#      'apiUrl': 'https://content.guardianapis.com/money/pensions',
#      'references': []},
#     {'id': 'society/benefits',
#      'type': 'keyword',
#      'sectionId': 'society',
#      'sectionName': 'Society',
#      'webTitle': 'Benefits',
#      'webUrl': 'https://www.theguardian.com/society/benefits',
#      'apiUrl': 'https://content.guardianapis.com/society/benefits',
#      'references': []},
#     {'id': 'politics/politics',
#      'type': 'keyword',
#      'sectionId': 'politics',
#      'sectionName': 'Politics',
#      'webTitle': 'Politics',
#      'webUrl': 'https://www.theguardian.com/politics/politics',
#      'apiUrl': 'https://content.guardianapis.com/politics/politics',
#      'references': [],
#      'description': '<p><br></p>'},
#     {'id': 'money/money',
#      'type': 'keyword',
#      'sectionId': 'money',
#      'sectionName': 'Money',
#      'webTitle': 'Money',
#      'webUrl': 'https://www.theguardian.com/money/money',
#      'apiUrl': 'https://content.guardianapis.com/money/money',
#      'references': []},
#     {'id': 'society/society',
#      'type': 'keyword',
#      'sectionId': 'society',
#      'sectionName': 'Society',
#      'webTitle': 'Society',
#      'webUrl': 'https://www.theguardian.com/society/society',
#      'apiUrl': 'https://content.guardianapis.com/society/society',
#      'references': []},
#     {'id': 'uk/uk',
#      'type': 'keyword',
#      'sectionId': 'uk-news',
#      'sectionName': 'UK news',
#      'webTitle': 'UK news',
#      'webUrl': 'https://www.theguardian.com/uk/uk',
#      'apiUrl': 'https://content.guardianapis.com/uk/uk',
#      'references': []}],
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'}]}

# %% [markdown]
# Convert first page of response to dataframe `df_response`:

# %%
df_response = pd.DataFrame(data_json['response']['results'])

# %%
df_response.head()
# Out:
#                                                   id     type       sectionId  \
# 0  football/2022/nov/12/harry-kane-world-cup-fitn...  article        football
# 1  australia-news/2022/nov/11/cruise-ship-majesti...  article  australia-news
# 2  us-news/2022/nov/11/democrat-mark-kelly-arizon...  article         us-news
# 3  australia-news/2022/nov/12/medibank-hack-clare...  article  australia-news
# 4  environment/2022/nov/12/replace-animal-farms-m...  article     environment
#
#       sectionName    webPublicationDate  \
# 0        Football  2022-11-12T00:04:24Z
# 1  Australia news  2022-11-12T00:35:40Z
# 2         US news  2022-11-12T03:46:54Z
# 3  Australia news  2022-11-12T03:47:17Z
# 4     Environment  2022-11-12T04:00:30Z
#
#                                             webTitle  \
# 0  England fans ‘must not worry’ about Harry Kane...
# 1  Majestic Princess: cruise ship passengers dise...
# 2  Mark Kelly holds on to Arizona seat in critica...
# 3  Medibank hack: Clare O’Neil says new cybercrim...
# 4  Replace animal farms with micro-organism tanks...
#
#                                               webUrl  \
# 0  https://www.theguardian.com/football/2022/nov/...
# 1  https://www.theguardian.com/australia-news/202...
# 2  https://www.theguardian.com/us-news/2022/nov/1...
# 3  https://www.theguardian.com/australia-news/202...
# 4  https://www.theguardian.com/environment/2022/n...
#
#                                               apiUrl  \
# 0  https://content.guardianapis.com/football/2022...
# 1  https://content.guardianapis.com/australia-new...
# 2  https://content.guardianapis.com/us-news/2022/...
# 3  https://content.guardianapis.com/australia-new...
# 4  https://content.guardianapis.com/environment/2...
#
#                                                 tags  isHosted      pillarId  \
# 0  [{'id': 'football/harry-kane', 'type': 'keywor...     False  pillar/sport
# 1  [{'id': 'australia-news/australia-news', 'type...     False   pillar/news
# 2  [{'id': 'us-news/us-midterm-elections-2022', '...     False   pillar/news
# 3  [{'id': 'australia-news/australian-politics', ...     False   pillar/news
# 4  [{'id': 'environment/food', 'type': 'keyword',...     False   pillar/news
#
#   pillarName
# 0      Sport
# 1       News
# 2       News
# 3       News
# 4       News

# %% [markdown]
# Get data from the second page to max number of pages from response and save these data to dataframe `df_response`:

# %%
count_of_pages = data_json['response']['pages']
for page in range(2,count_of_pages+1):
    response = requests.get(url_querry  + '&' + 'page=' + str(page))
    data_json = response.json()
    df_page = pd.DataFrame(data_json['response']['results'])
    frames = [df_response, df_page]
    result = pd.concat(frames)
    df_response = result
    print('Processed {}/{} - {:2.2%}'.format(page,count_of_pages,page/count_of_pages))
# Out:
# Processed 2/32 - 6.25%
# Processed 3/32 - 9.38%
# Processed 4/32 - 12.50%
# Processed 5/32 - 15.62%
# Processed 6/32 - 18.75%
# Processed 7/32 - 21.88%
# Processed 8/32 - 25.00%
# Processed 9/32 - 28.12%
# Processed 10/32 - 31.25%
# Processed 11/32 - 34.38%
# Processed 12/32 - 37.50%
# Processed 13/32 - 40.62%
# Processed 14/32 - 43.75%
# Processed 15/32 - 46.88%
# Processed 16/32 - 50.00%
# Processed 17/32 - 53.12%
# Processed 18/32 - 56.25%
# Processed 19/32 - 59.38%
# Processed 20/32 - 62.50%
# Processed 21/32 - 65.62%
# Processed 22/32 - 68.75%
# Processed 23/32 - 71.88%
# Processed 24/32 - 75.00%
# Processed 25/32 - 78.12%
# Processed 26/32 - 81.25%
# Processed 27/32 - 84.38%
# Processed 28/32 - 87.50%
# Processed 29/32 - 90.62%
# Processed 30/32 - 93.75%
# Processed 31/32 - 96.88%
# Processed 32/32 - 100.00%

# %%
data_json
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 316,
#   'startIndex': 311,
#   'pageSize': 10,
#   'currentPage': 32,
#   'pages': 32,
#   'orderBy': 'oldest',
#   'results': [{'id': 'australia-news/2022/nov/14/medibank-mental-health-data-posted-on-dark-web-as-russian-hackers-vow-to-keep-our-word',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2022-11-13T21:39:38Z',
#     'webTitle': 'Medibank mental health data posted on dark web as Russian hackers vow to ‘keep our word’',
#     'webUrl': 'https://www.theguardian.com/australia-news/2022/nov/14/medibank-mental-health-data-posted-on-dark-web-as-russian-hackers-vow-to-keep-our-word',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2022/nov/14/medibank-mental-health-data-posted-on-dark-web-as-russian-hackers-vow-to-keep-our-word',
#     'tags': [{'id': 'australia-news/medibank',
#       'type': 'keyword',
#       'sectionId': 'australia-news',
#       'sectionName': 'Australia news',
#       'webTitle': 'Medibank',
#       'webUrl': 'https://www.theguardian.com/australia-news/medibank',
#       'apiUrl': 'https://content.guardianapis.com/australia-news/medibank',
#       'references': []},
#      {'id': 'technology/cybercrime',
#       'type': 'keyword',
#       'sectionId': 'technology',
#       'sectionName': 'Technology',
#       'webTitle': 'Cybercrime',
#       'webUrl': 'https://www.theguardian.com/technology/cybercrime',
#       'apiUrl': 'https://content.guardianapis.com/technology/cybercrime',
#       'references': []},
#      {'id': 'australia-news/australia-news',
#       'type': 'keyword',
#       'sectionId': 'australia-news',
#       'sectionName': 'Australia news',
#       'webTitle': 'Australia news',
#       'webUrl': 'https://www.theguardian.com/australia-news/australia-news',
#       'apiUrl': 'https://content.guardianapis.com/australia-news/australia-news',
#       'references': []},
#      {'id': 'australia-news/australian-federal-police',
#       'type': 'keyword',
#       'sectionId': 'australia-news',
#       'sectionName': 'Australia news',
#       'webTitle': 'Australian federal police',
#       'webUrl': 'https://www.theguardian.com/australia-news/australian-federal-police',
#       'apiUrl': 'https://content.guardianapis.com/australia-news/australian-federal-police',
#       'references': [],
#       'description': 'The AFP is the national law enforcement agency of Australia'},
#      {'id': 'australia-news/clare-o-neil',
#       'type': 'keyword',
#       'sectionId': 'australia-news',
#       'sectionName': 'Australia news',
#       'webTitle': "Clare O'Neil",
#       'webUrl': 'https://www.theguardian.com/australia-news/clare-o-neil',
#       'apiUrl': 'https://content.guardianapis.com/australia-news/clare-o-neil',
#       'references': []}],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'world/2022/nov/13/mines-looting-no-power-kherson-assesses-damage-after-russian-retreat',
#     'type': 'article',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webPublicationDate': '2022-11-13T22:19:22Z',
#     'webTitle': 'Zelenskiy accuses Russia of Kherson war crimes',
#     'webUrl': 'https://www.theguardian.com/world/2022/nov/13/mines-looting-no-power-kherson-assesses-damage-after-russian-retreat',
#     'apiUrl': 'https://content.guardianapis.com/world/2022/nov/13/mines-looting-no-power-kherson-assesses-damage-after-russian-retreat',
#     'tags': [{'id': 'world/ukraine',
#       'type': 'keyword',
#       'sectionId': 'world',
#       'sectionName': 'World news',
#       'webTitle': 'Ukraine',
#       'webUrl': 'https://www.theguardian.com/world/ukraine',
#       'apiUrl': 'https://content.guardianapis.com/world/ukraine',
#       'references': []},
#      {'id': 'world/russia',
#       'type': 'keyword',
#       'sectionId': 'world',
#       'sectionName': 'World news',
#       'webTitle': 'Russia',
#       'webUrl': 'https://www.theguardian.com/world/russia',
#       'apiUrl': 'https://content.guardianapis.com/world/russia',
#       'references': []},
#      {'id': 'world/europe-news',
#       'type': 'keyword',
#       'sectionId': 'world',
#       'sectionName': 'World news',
#       'webTitle': 'Europe',
#       'webUrl': 'https://www.theguardian.com/world/europe-news',
#       'apiUrl': 'https://content.guardianapis.com/world/europe-news',
#       'references': []},
#      {'id': 'world/world',
#       'type': 'keyword',
#       'sectionId': 'world',
#       'sectionName': 'World news',
#       'webTitle': 'World news',
#       'webUrl': 'https://www.theguardian.com/world/world',
#       'apiUrl': 'https://content.guardianapis.com/world/world',
#       'references': []}],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'sport/2022/nov/13/russell-admits-tears-were-flooding-after-emotional-f1-breakthrough-in-sao-paulo',
#     'type': 'article',
#     'sectionId': 'sport',
#     'sectionName': 'Sport',
#     'webPublicationDate': '2022-11-13T22:23:14Z',
#     'webTitle': 'Russell admits ‘tears were flooding’ after emotional F1 breakthrough in São Paulo',
#     'webUrl': 'https://www.theguardian.com/sport/2022/nov/13/russell-admits-tears-were-flooding-after-emotional-f1-breakthrough-in-sao-paulo',
#     'apiUrl': 'https://content.guardianapis.com/sport/2022/nov/13/russell-admits-tears-were-flooding-after-emotional-f1-breakthrough-in-sao-paulo',
#     'tags': [{'id': 'sport/formulaone',
#       'type': 'keyword',
#       'sectionId': 'sport',
#       'sectionName': 'Sport',
#       'webTitle': 'Formula One',
#       'webUrl': 'https://www.theguardian.com/sport/formulaone',
#       'apiUrl': 'https://content.guardianapis.com/sport/formulaone',
#       'references': []},
#      {'id': 'sport/mercedes-gp',
#       'type': 'keyword',
#       'sectionId': 'sport',
#       'sectionName': 'Sport',
#       'webTitle': 'Mercedes GP',
#       'webUrl': 'https://www.theguardian.com/sport/mercedes-gp',
#       'apiUrl': 'https://content.guardianapis.com/sport/mercedes-gp',
#       'references': []},
#      {'id': 'sport/motorsports',
#       'type': 'keyword',
#       'sectionId': 'sport',
#       'sectionName': 'Sport',
#       'webTitle': 'Motor sport',
#       'webUrl': 'https://www.theguardian.com/sport/motorsports',
#       'apiUrl': 'https://content.guardianapis.com/sport/motorsports',
#       'references': []},
#      {'id': 'sport/sport',
#       'type': 'keyword',
#       'sectionId': 'sport',
#       'sectionName': 'Sport',
#       'webTitle': 'Sport',
#       'webUrl': 'https://www.theguardian.com/sport/sport',
#       'apiUrl': 'https://content.guardianapis.com/sport/sport',
#       'references': []}],
#     'isHosted': False,
#     'pillarId': 'pillar/sport',
#     'pillarName': 'Sport'},
#    {'id': 'uk-news/2022/nov/13/joe-biden-to-meet-rishi-sunak-northern-ireland-protocol',
#     'type': 'article',
#     'sectionId': 'uk-news',
#     'sectionName': 'UK news',
#     'webPublicationDate': '2022-11-13T22:30:22Z',
#     'webTitle': 'Biden to meet Sunak as pressure grows on PM over Northern Ireland protocol',
#     'webUrl': 'https://www.theguardian.com/uk-news/2022/nov/13/joe-biden-to-meet-rishi-sunak-northern-ireland-protocol',
#     'apiUrl': 'https://content.guardianapis.com/uk-news/2022/nov/13/joe-biden-to-meet-rishi-sunak-northern-ireland-protocol',
#     'tags': [{'id': 'uk/northernireland',
#       'type': 'keyword',
#       'sectionId': 'uk-news',
#       'sectionName': 'UK news',
#       'webTitle': 'Northern Ireland',
#       'webUrl': 'https://www.theguardian.com/uk/northernireland',
#       'apiUrl': 'https://content.guardianapis.com/uk/northernireland',
#       'references': [],
#       'description': 'The latest news and comment on Northern Ireland'},
#      {'id': 'us-news/joebiden',
#       'type': 'keyword',
#       'sectionId': 'us-news',
#       'sectionName': 'US news',
#       'webTitle': 'Joe Biden',
#       'webUrl': 'https://www.theguardian.com/us-news/joebiden',
#       'apiUrl': 'https://content.guardianapis.com/us-news/joebiden',
#       'references': []},
#      {'id': 'politics/rishi-sunak',
#       'type': 'keyword',
#       'sectionId': 'politics',
#       'sectionName': 'Politics',
#       'webTitle': 'Rishi Sunak',
#       'webUrl': 'https://www.theguardian.com/politics/rishi-sunak',
#       'apiUrl': 'https://content.guardianapis.com/politics/rishi-sunak',
#       'references': []},
#      {'id': 'politics/eu-referendum',
#       'type': 'keyword',
#       'sectionId': 'politics',
#       'sectionName': 'Politics',
#       'webTitle': 'Brexit',
#       'webUrl': 'https://www.theguardian.com/politics/eu-referendum',
#       'apiUrl': 'https://content.guardianapis.com/politics/eu-referendum',
#       'references': []},
#      {'id': 'world/g20',
#       'type': 'keyword',
#       'sectionId': 'world',
#       'sectionName': 'World news',
#       'webTitle': 'G20',
#       'webUrl': 'https://www.theguardian.com/world/g20',
#       'apiUrl': 'https://content.guardianapis.com/world/g20',
#       'references': []},
#      {'id': 'world/ukraine',
#       'type': 'keyword',
#       'sectionId': 'world',
#       'sectionName': 'World news',
#       'webTitle': 'Ukraine',
#       'webUrl': 'https://www.theguardian.com/world/ukraine',
#       'apiUrl': 'https://content.guardianapis.com/world/ukraine',
#       'references': []},
#      {'id': 'world/russia',
#       'type': 'keyword',
#       'sectionId': 'world',
#       'sectionName': 'World news',
#       'webTitle': 'Russia',
#       'webUrl': 'https://www.theguardian.com/world/russia',
#       'apiUrl': 'https://content.guardianapis.com/world/russia',
#       'references': []},
#      {'id': 'world/world',
#       'type': 'keyword',
#       'sectionId': 'world',
#       'sectionName': 'World news',
#       'webTitle': 'World news',
#       'webUrl': 'https://www.theguardian.com/world/world',
#       'apiUrl': 'https://content.guardianapis.com/world/world',
#       'references': []},
#      {'id': 'uk/uk',
#       'type': 'keyword',
#       'sectionId': 'uk-news',
#       'sectionName': 'UK news',
#       'webTitle': 'UK news',
#       'webUrl': 'https://www.theguardian.com/uk/uk',
#       'apiUrl': 'https://content.guardianapis.com/uk/uk',
#       'references': []},
#      {'id': 'politics/politics',
#       'type': 'keyword',
#       'sectionId': 'politics',
#       'sectionName': 'Politics',
#       'webTitle': 'Politics',
#       'webUrl': 'https://www.theguardian.com/politics/politics',
#       'apiUrl': 'https://content.guardianapis.com/politics/politics',
#       'references': [],
#       'description': '<p><br></p>'},
#      {'id': 'us-news/us-news',
#       'type': 'keyword',
#       'sectionId': 'us-news',
#       'sectionName': 'US news',
#       'webTitle': 'US news',
#       'webUrl': 'https://www.theguardian.com/us-news/us-news',
#       'apiUrl': 'https://content.guardianapis.com/us-news/us-news',
#       'references': []}],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'uk-news/2022/nov/13/sunak-says-higher-taxes-and-spending-cuts-needed-to-satisfy-markets',
#     'type': 'article',
#     'sectionId': 'uk-news',
#     'sectionName': 'UK news',
#     'webPublicationDate': '2022-11-13T22:30:22Z',
#     'webTitle': 'Sunak says higher taxes and spending cuts needed to satisfy markets',
#     'webUrl': 'https://www.theguardian.com/uk-news/2022/nov/13/sunak-says-higher-taxes-and-spending-cuts-needed-to-satisfy-markets',
#     'apiUrl': 'https://content.guardianapis.com/uk-news/2022/nov/13/sunak-says-higher-taxes-and-spending-cuts-needed-to-satisfy-markets',
#     'tags': [{'id': 'uk/uk',
#       'type': 'keyword',
#       'sectionId': 'uk-news',
#       'sectionName': 'UK news',
#       'webTitle': 'UK news',
#       'webUrl': 'https://www.theguardian.com/uk/uk',
#       'apiUrl': 'https://content.guardianapis.com/uk/uk',
#       'references': []},
#      {'id': 'business/cost-of-living-crisis',
#       'type': 'keyword',
#       'sectionId': 'business',
#       'sectionName': 'Business',
#       'webTitle': 'UK cost of living crisis',
#       'webUrl': 'https://www.theguardian.com/business/cost-of-living-crisis',
#       'apiUrl': 'https://content.guardianapis.com/business/cost-of-living-crisis',
#       'references': []},
#      {'id': 'politics/rishi-sunak',
#       'type': 'keyword',
#       'sectionId': 'politics',
#       'sectionName': 'Politics',
#       'webTitle': 'Rishi Sunak',
#       'webUrl': 'https://www.theguardian.com/politics/rishi-sunak',
#       'apiUrl': 'https://content.guardianapis.com/politics/rishi-sunak',
#       'references': []},
#      {'id': 'politics/jeremy-hunt',
#       'type': 'keyword',
#       'sectionId': 'politics',
#       'sectionName': 'Politics',
#       'webTitle': 'Jeremy Hunt',
#       'webUrl': 'https://www.theguardian.com/politics/jeremy-hunt',
#       'apiUrl': 'https://content.guardianapis.com/politics/jeremy-hunt',
#       'references': []},
#      {'id': 'world/g20',
#       'type': 'keyword',
#       'sectionId': 'world',
#       'sectionName': 'World news',
#       'webTitle': 'G20',
#       'webUrl': 'https://www.theguardian.com/world/g20',
#       'apiUrl': 'https://content.guardianapis.com/world/g20',
#       'references': []},
#      {'id': 'politics/politics',
#       'type': 'keyword',
#       'sectionId': 'politics',
#       'sectionName': 'Politics',
#       'webTitle': 'Politics',
#       'webUrl': 'https://www.theguardian.com/politics/politics',
#       'apiUrl': 'https://content.guardianapis.com/politics/politics',
#       'references': [],
#       'description': '<p><br></p>'}],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'tv-and-radio/2022/nov/13/young-black-and-right-wing-review-channel-4',
#     'type': 'article',
#     'sectionId': 'tv-and-radio',
#     'sectionName': 'Television & radio',
#     'webPublicationDate': '2022-11-13T22:55:22Z',
#     'webTitle': 'Young, Black and Right-Wing review – you’ll never believe who their heroes are ',
#     'webUrl': 'https://www.theguardian.com/tv-and-radio/2022/nov/13/young-black-and-right-wing-review-channel-4',
#     'apiUrl': 'https://content.guardianapis.com/tv-and-radio/2022/nov/13/young-black-and-right-wing-review-channel-4',
#     'tags': [{'id': 'culture/television',
#       'type': 'keyword',
#       'sectionId': 'tv-and-radio',
#       'sectionName': 'Television & radio',
#       'webTitle': 'Television',
#       'webUrl': 'https://www.theguardian.com/culture/television',
#       'apiUrl': 'https://content.guardianapis.com/culture/television',
#       'references': []},
#      {'id': 'tv-and-radio/tv-and-radio',
#       'type': 'keyword',
#       'sectionId': 'tv-and-radio',
#       'sectionName': 'Television & radio',
#       'webTitle': 'Television & radio',
#       'webUrl': 'https://www.theguardian.com/tv-and-radio/tv-and-radio',
#       'apiUrl': 'https://content.guardianapis.com/tv-and-radio/tv-and-radio',
#       'references': []},
#      {'id': 'culture/culture',
#       'type': 'keyword',
#       'sectionId': 'culture',
#       'sectionName': 'Culture',
#       'webTitle': 'Culture',
#       'webUrl': 'https://www.theguardian.com/culture/culture',
#       'apiUrl': 'https://content.guardianapis.com/culture/culture',
#       'references': []}],
#     'isHosted': False,
#     'pillarId': 'pillar/arts',
#     'pillarName': 'Arts'}]}}

# %%
df_response = df_response.reset_index()

# %%
df_response = df_response.drop(columns=['index'])

# %%
df_response['id_num'] = range(1, len(df_response) + 1)

# %% [markdown]
# ## 2. Save general information about article

# %%
df_article = df_response[['id_num',
               'id', 
               'type', 
               'sectionId',
               'sectionName',
               'webPublicationDate',
               'webTitle',
               'isHosted',
               'pillarId',
               'pillarName'
              ]]

# %%
df_article.head()
# Out:
#    id_num                                                 id     type  \
# 0       1  football/2022/nov/12/harry-kane-world-cup-fitn...  article
# 1       2  australia-news/2022/nov/11/cruise-ship-majesti...  article
# 2       3  us-news/2022/nov/11/democrat-mark-kelly-arizon...  article
# 3       4  australia-news/2022/nov/12/medibank-hack-clare...  article
# 4       5  environment/2022/nov/12/replace-animal-farms-m...  article
#
#         sectionId     sectionName    webPublicationDate  \
# 0        football        Football  2022-11-12T00:04:24Z
# 1  australia-news  Australia news  2022-11-12T00:35:40Z
# 2         us-news         US news  2022-11-12T03:46:54Z
# 3  australia-news  Australia news  2022-11-12T03:47:17Z
# 4     environment     Environment  2022-11-12T04:00:30Z
#
#                                             webTitle  isHosted      pillarId  \
# 0  England fans ‘must not worry’ about Harry Kane...     False  pillar/sport
# 1  Majestic Princess: cruise ship passengers dise...     False   pillar/news
# 2  Mark Kelly holds on to Arizona seat in critica...     False   pillar/news
# 3  Medibank hack: Clare O’Neil says new cybercrim...     False   pillar/news
# 4  Replace animal farms with micro-organism tanks...     False   pillar/news
#
#   pillarName
# 0      Sport
# 1       News
# 2       News
# 3       News
# 4       News

# %%
name_csv = 'general/guardian-article-data_start-date-' + from_date + '_end-date-' + to_date + '_general.csv'

# %%
df_article.to_csv(name_csv,index=False,sep=';')

# %% [markdown]
# ## 3. Save tag information

# %%
df_tags = df_response[['id_num',
               'id',
               'tags'
              ]]

# %%
df_tags.head()
# Out:
#    id_num                                                 id  \
# 0       1  football/2022/nov/12/harry-kane-world-cup-fitn...
# 1       2  australia-news/2022/nov/11/cruise-ship-majesti...
# 2       3  us-news/2022/nov/11/democrat-mark-kelly-arizon...
# 3       4  australia-news/2022/nov/12/medibank-hack-clare...
# 4       5  environment/2022/nov/12/replace-animal-farms-m...
#
#                                                 tags
# 0  [{'id': 'football/harry-kane', 'type': 'keywor...
# 1  [{'id': 'australia-news/australia-news', 'type...
# 2  [{'id': 'us-news/us-midterm-elections-2022', '...
# 3  [{'id': 'australia-news/australian-politics', ...
# 4  [{'id': 'environment/food', 'type': 'keyword',...

# %%
pd.DataFrame(df_tags.iloc[3]['tags'])
# Out:
#                                    id     type       sectionId  \
# 0  australia-news/australian-politics  keyword  australia-news
# 1          australia-news/labor-party  keyword  australia-news
# 2            australia-news/coalition  keyword  australia-news
# 3       australia-news/australia-news  keyword  australia-news
# 4                        world/russia  keyword           world
# 5             australia-news/medibank  keyword  australia-news
# 6      australia-news/crime-australia  keyword  australia-news
#
#       sectionName             webTitle  \
# 0  Australia news  Australian politics
# 1  Australia news          Labor party
# 2  Australia news            Coalition
# 3  Australia news       Australia news
# 4      World news               Russia
# 5  Australia news             Medibank
# 6  Australia news    Crime - Australia
#
#                                               webUrl  \
# 0  https://www.theguardian.com/australia-news/aus...
# 1  https://www.theguardian.com/australia-news/lab...
# 2  https://www.theguardian.com/australia-news/coa...
# 3  https://www.theguardian.com/australia-news/aus...
# 4           https://www.theguardian.com/world/russia
# 5  https://www.theguardian.com/australia-news/med...
# 6  https://www.theguardian.com/australia-news/cri...
#
#                                               apiUrl references  \
# 0  https://content.guardianapis.com/australia-new...         []
# 1  https://content.guardianapis.com/australia-new...         []
# 2  https://content.guardianapis.com/australia-new...         []
# 3  https://content.guardianapis.com/australia-new...         []
# 4      https://content.guardianapis.com/world/russia         []
# 5  https://content.guardianapis.com/australia-new...         []
# 6  https://content.guardianapis.com/australia-new...         []
#
#                                          description
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  Latest news on crime in Australia from the Gua...

# %%
name_json = 'guardian-article-data_start-date-' + from_date + '_end-date-' + to_date + '_pre-tags.json'

# %%
df_tags.to_json(name_json,orient="records")

# %%
with open(name_json,'r') as f:
    data = json.loads(f.read())

# %%
df_tag = pd.json_normalize(data, 
                           record_path =['tags'], 
                           meta =['id_num','id'],
                           record_prefix='tag_')

# %%
df_tag = df_tag[['id_num',
               'id',
               'tag_id',
               'tag_sectionName',
               'tag_webTitle',
               'tag_description'
              ]]

# %%
df_tag.head()
# Out:
#   id_num                                                 id  \
# 0      1  football/2022/nov/12/harry-kane-world-cup-fitn...
# 1      1  football/2022/nov/12/harry-kane-world-cup-fitn...
# 2      1  football/2022/nov/12/harry-kane-world-cup-fitn...
# 3      1  football/2022/nov/12/harry-kane-world-cup-fitn...
# 4      1  football/2022/nov/12/harry-kane-world-cup-fitn...
#
#                        tag_id tag_sectionName       tag_webTitle  \
# 0         football/harry-kane        Football         Harry Kane
# 1     football/world-cup-2022        Football     World Cup 2022
# 2            football/england        Football            England
# 3  football/tottenham-hotspur        Football  Tottenham Hotspur
# 4           football/football        Football           Football
#
#                                      tag_description
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Read the latest Tottenham Hotspur news, transf...
# 4                                                NaN

# %%
name_csv = 'tags/guardian-article-data_start-date-' + from_date + '_end-date-' + to_date + '_tags.csv'

# %%
df_tag.to_csv(name_csv,index=False,sep=';')

# %%
df_tag[df_tag['tag_webTitle'] == 'Justin Trudeau']
# Out:
# Empty DataFrame
# Columns: [id_num, id, tag_id, tag_sectionName, tag_webTitle, tag_description]
# Index: []
